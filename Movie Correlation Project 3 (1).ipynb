# %%
############################################################
# import librarii
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

############################################################
#Citire date 
df = pd.read_csv (r'C:\Users\adica\Documents\Portofoliu Data Analyst\movies project 3.csv')

# %%
#Privim datele 
df.head() #afiseaza primele 5 randuri
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
#Verificam daca exista valori lipsa
for col in df.columns:
    pct_missing = np.mean(df[col].isnull()) * 100
    print ('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 1.004173187271779%
# genre - 0.0%
# year - 0.0%
# released - 0.02608242044861763%
# score - 0.03912363067292645%
# votes - 0.03912363067292645%
# director - 0.0%
# writer - 0.03912363067292645%
# star - 0.013041210224308816%
# country - 0.03912363067292645%
# budget - 28.31246739697444%
# gross - 2.464788732394366%
# company - 0.2217005738132499%
# runtime - 0.05216484089723526%

# %%
#Verificam tipurile datelor pentru fiecare coloana
df.dtypes
# Out:
# name            str
# rating          str
# genre           str
# year          int64
# released        str
# score       float64
# votes       float64
# director        str
# writer          str
# star            str
# country         str
# budget      float64
# gross       float64
# company         str
# runtime     float64
# dtype: object

# %%
#Schimbam tipul de data pentru coloanele si gross din motive estetice si punem 0 in locul valorilor lipsa 
df['budget'] = df['budget'].fillna(0).astype('int64')
df['gross'] = df['gross'].fillna(0).astype('int64')

# %%
#Verificam setul de date 
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.    146.0
# 1   58853106   Columbia Pictures    104.0
# 2  538375067           Lucasfilm    124.0
# 3   83453539  Paramount Pictures     88.0
# 4   39846344      Orion Pictures     98.0

# %%
#Schimbam tipul coloanei released pentru a extrage anul din cadrul ei si realizam o noua coloana care sa il contina
df['released'] = df['released'].astype ('str')
df['yearcorrect'] = df['released'].str.extract(r'(\d{4})') #functie prin intermediul careia imi sunt extrase din text 4 cifre consecutive
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime yearcorrect
# 0   46998772        Warner Bros.    146.0        1980
# 1   58853106   Columbia Pictures    104.0        1980
# 2  538375067           Lucasfilm    124.0        1980
# 3   83453539  Paramount Pictures     88.0        1980
# 4   39846344      Orion Pictures     98.0        1980

# %%
#Sortam datele de la de la cea mai mare valoare din coloana gross catre cea mai mica
df.sort_values (by = ['gross'], inplace=True,  ascending = False)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox    162.0        2009
# 7445  2797501328         Marvel Studios    181.0        2019
# 3045  2201647264  Twentieth Century Fox    194.0        1997
# 6663  2069521700              Lucasfilm    138.0        2015
# 7244  2048359754         Marvel Studios    149.0        2018

# %%
pd.set_option('display.max_rows', None) #pentru a vizualiza toate datele

# %%
#Eliminam duplicatele
#df.drop_duplicates()

# %%
#Construim un scatter plot pentru a vizualiza legatura dintre buget si gross
plt.scatter (x=df['budget'], y=df['gross'])
plt.title ('Budget vs. Gross')
plt.xlabel('Budget')
plt.ylabel('Gross')
plt.show()

# %%
#Grafic care pune in evidenta budget vs gross prin utilizarea seaborn
sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color" : "black"}, line_kws={"color" : "purple"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
#Coeficient de corelatie pentru variabilele numerice (Pearson)
df.corr(numeric_only=True)
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
#Coeficient de corelatie pentru variabilele numerice (Kendall) - compara perechi de observatii si observa daca ele cresc in aceeasi directie
df.corr(numeric_only=True, method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.209304  0.216595  0.097184
# score    0.067652  1.000000  0.300115 -0.005194  0.090626  0.283611
# votes    0.331465  0.300115  1.000000  0.439902  0.560118  0.198240
# budget   0.209304 -0.005194  0.439902  1.000000  0.541956  0.176016
# gross    0.216595  0.090626  0.560118  0.541956  1.000000  0.176912
# runtime  0.097184  0.283611  0.198240  0.176016  0.176912  1.000000

# %%
#Coeficient de corelatie pentru variabilele numerice (Spearman) - asemanator kendall
df.corr(numeric_only=True, method='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.291152  0.314681  0.142977
# score    0.099045  1.000000  0.428138 -0.007500  0.132569  0.399857
# votes    0.469829  0.428138  1.000000  0.604627  0.752265  0.290159
# budget   0.291152 -0.007500  0.604627  1.000000  0.716816  0.246748
# gross    0.314681  0.132569  0.752265  0.716816  1.000000  0.256783
# runtime  0.142977  0.399857  0.290159  0.246748  0.256783  1.000000

# %%
#Se observa un coeficent mare de corelarie intre gross si budget
correlation_matrix = df.corr(numeric_only=True)
sns.heatmap (correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie_Features')
plt.ylabel('Movie_Features')
plt.show()

# %%
#Pentru a verifica corelatia dintre companny si gross este necesar sa transformam coloanele care nu sunt numerice

df_numeric = df.copy()
for col_name in df_numeric.columns:
    if(df_numeric[col_name].dtype != 'int64'):
       df_numeric[col_name] = df_numeric[col_name].astype ('category')
       df_numeric[col_name] = df_numeric[col_name].cat.codes
df_numeric.head()
# Out:
#    name  rating  genre  year  released  score  votes  director  writer  star  \
# 0  6587       6      6  1980      1705     64    914      2589    4014  1047
# 1  5573       6      1  1980      1492     38    393      2269    1632   327
# 2  5142       4      0  1980      1771     67    927      1111    2567  1745
# 3   286       4      4  1980      1492     57    548      1301    2000  2246
# 4  1027       6      4  1980      1543     53    436      1054     521   410
#
#    country    budget      gross  company  runtime  yearcorrect
# 0       54  19000000   46998772     2319       78            0
# 1       55   4500000   58853106      731       36            0
# 2       55  18000000  538375067     1540       56            0
# 3       55   3500000   83453539     1812       20            0
# 4       55   6000000   39846344     1777       30            0

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime yearcorrect
# 5445  2847246203  Twentieth Century Fox    162.0        2009
# 7445  2797501328         Marvel Studios    181.0        2019
# 3045  2201647264  Twentieth Century Fox    194.0        1997
# 6663  2069521700              Lucasfilm    138.0        2015
# 7244  2048359754         Marvel Studios    149.0        2018

# %%
#Realizam matricea de corelatie pentru toate observatiile din data frame tranformate in valori numerice
correlation_matrix_numeric = df_numeric.corr(numeric_only=True)
sns.heatmap (correlation_matrix_numeric, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie_Features')
plt.ylabel('Movie_Features')
plt.show()

# %%
#Valorile din matricea anterioara
df_numeric.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.016598
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613  0.003950
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027592
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.094416
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.040699
# score        0.016598  0.003950  0.027592  0.094416  0.040699  1.000000
# votes        0.007497  0.074561 -0.185332  0.355072  0.002601  0.458517
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.010307
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.021313
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.000542
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133644
# budget       0.020548 -0.081939 -0.334021  0.309212  0.009145  0.056609
# gross        0.006989 -0.095450 -0.234297  0.261900  0.000519  0.186490
# company      0.009211 -0.032943 -0.071067 -0.010431 -0.010474  0.003911
# runtime      0.009920  0.067150 -0.057637  0.125994  0.000641  0.406004
# yearcorrect  0.010225  0.006403 -0.078210  0.996397 -0.003775  0.102718
#
#                 votes  director    writer      star   country    budget  \
# name         0.007497  0.009079  0.009081  0.006472 -0.010737  0.020548
# rating       0.074561  0.019483 -0.005921  0.013405  0.081244 -0.081939
# genre       -0.185332 -0.015258  0.006567 -0.005477 -0.037615 -0.334021
# year         0.355072 -0.020795 -0.008656 -0.027242 -0.070938  0.309212
# released     0.002601 -0.001478 -0.002404  0.015777 -0.020427  0.009145
# score        0.458517  0.010307  0.021313 -0.000542 -0.133644  0.056609
# votes        1.000000  0.007427  0.007744 -0.020851  0.083126  0.555783
# director     0.007427  1.000000  0.299067  0.039234  0.017490  0.004976
# writer       0.007744  0.299067  1.000000  0.027245  0.015343 -0.025911
# star        -0.020851  0.039234  0.027245  1.000000 -0.012998 -0.019952
# country      0.083126  0.017490  0.015343 -0.012998  1.000000  0.131720
# budget       0.555783  0.004976 -0.025911 -0.019952  0.131720  1.000000
# gross        0.637628 -0.014916 -0.022997 -0.001129  0.095325  0.750157
# company      0.168983  0.004404  0.005646  0.012442  0.095548  0.186474
# runtime      0.337200  0.018408 -0.004417  0.009449 -0.076787  0.280730
# yearcorrect  0.349291 -0.020385 -0.008391 -0.027606 -0.079009  0.300236
#
#                 gross   company   runtime  yearcorrect
# name         0.006989  0.009211  0.009920     0.010225
# rating      -0.095450 -0.032943  0.067150     0.006403
# genre       -0.234297 -0.071067 -0.057637    -0.078210
# year         0.261900 -0.010431  0.125994     0.996397
# released     0.000519 -0.010474  0.000641    -0.003775
# score        0.186490  0.003911  0.406004     0.102718
# votes        0.637628  0.168983  0.337200     0.349291
# director    -0.014916  0.004404  0.018408    -0.020385
# writer      -0.022997  0.005646 -0.004417    -0.008391
# star        -0.001129  0.012442  0.009449    -0.027606
# country      0.095325  0.095548 -0.076787    -0.079009
# budget       0.750157  0.186474  0.280730     0.300236
# gross        1.000000  0.156745  0.255656     0.255130
# company      0.156745  1.000000  0.036970    -0.014144
# runtime      0.255656  0.036970  1.000000     0.127376
# yearcorrect  0.255130 -0.014144  0.127376     1.000000

# %%
#O varianta de a vizualiza mai usor valorile din matricea de corelatie
correlation_mat = df_numeric.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.016598
#              votes          0.007497
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.020548
#              gross          0.006989
#              company        0.009211
#              runtime        0.009920
#              yearcorrect    0.010225
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score          0.003950
#              votes          0.074561
#              director       0.019483
#              writer        -0.005921
#              star           0.013405
#              country        0.081244
#              budget        -0.081939
#              gross         -0.095450
#              company       -0.032943
#              runtime        0.067150
#              yearcorrect    0.006403
# genre        name           0.016355
#              rating         0.072423
#              genre          1.000000
#              year          -0.081261
#              released       0.029822
#              score          0.027592
#              votes         -0.185332
#              director      -0.015258
#              writer         0.006567
#              star          -0.005477
#              country       -0.037615
#              budget        -0.334021
#              gross         -0.234297
#              company       -0.071067
#              runtime       -0.057637
#              yearcorrect   -0.078210
# year         name           0.011453
#              rating         0.008779
#              genre         -0.081261
#              year           1.000000
#              released      -0.000695
#              score          0.094416
#              votes          0.355072
#              director      -0.020795
#              writer        -0.008656
#              star          -0.027242
#              country       -0.070938
#              budget         0.309212
#              gross          0.261900
#              company       -0.010431
#              runtime        0.125994
#              yearcorrect    0.996397
# released     name          -0.011311
#              rating         0.016613
#              genre          0.029822
#              year          -0.000695
#              released       1.000000
#              score          0.040699
#              votes          0.002601
#              director      -0.001478
#              writer        -0.002404
#              star           0.015777
#              country       -0.020427
#              budget         0.009145
#              gross          0.000519
#              company       -0.010474
#              runtime        0.000641
#              yearcorrect   -0.003775
# score        name           0.016598
#              rating         0.003950
#              genre          0.027592
#              year           0.094416
#              released       0.040699
#              score          1.000000
#              votes          0.458517
#              director       0.010307
#              writer         0.021313
#              star          -0.000542
#              country       -0.133644
#              budget         0.056609
#              gross          0.186490
#              company        0.003911
#              runtime        0.406004
#              yearcorrect    0.102718
# votes        name           0.007497
#              rating         0.074561
#              genre         -0.185332
#              year           0.355072
#              released       0.002601
#              score          0.458517
#              votes          1.000000
#              director       0.007427
#              writer         0.007744
#              star          -0.020851
#              country        0.083126
#              budget         0.555783
#              gross          0.637628
#              company        0.168983
#              runtime        0.337200
#              yearcorrect    0.349291
# director     name           0.009079
#              rating         0.019483
#              genre         -0.015258
#              year          -0.020795
#              released      -0.001478
#              score          0.010307
#              votes          0.007427
#              director       1.000000
#              writer         0.299067
#              star           0.039234
#              country        0.017490
#              budget         0.004976
#              gross         -0.014916
#              company        0.004404
#              runtime        0.018408
#              yearcorrect   -0.020385
# writer       name           0.009081
#              rating        -0.005921
#              genre          0.006567
#              year          -0.008656
#              released      -0.002404
#              score          0.021313
#              votes          0.007744
#              director       0.299067
#              writer         1.000000
#              star           0.027245
#              country        0.015343
#              budget        -0.025911
#              gross         -0.022997
#              company        0.005646
#              runtime       -0.004417
#              yearcorrect   -0.008391
# star         name           0.006472
#              rating         0.013405
#              genre         -0.005477
#              year          -0.027242
#              released       0.015777
#              score         -0.000542
#              votes         -0.020851
#              director       0.039234
#              writer         0.027245
#              star           1.000000
#              country       -0.012998
#              budget        -0.019952
#              gross         -0.001129
#              company        0.012442
#              runtime        0.009449
#              yearcorrect   -0.027606
# country      name          -0.010737
#              rating         0.081244
#              genre         -0.037615
#              year          -0.070938
#              released      -0.020427
#              score         -0.133644
#              votes          0.083126
#              director       0.017490
#              writer         0.015343
#              star          -0.012998
#              country        1.000000
#              budget         0.131720
#              gross          0.095325
#              company        0.095548
#              runtime       -0.076787
#              yearcorrect   -0.079009
# budget       name           0.020548
#              rating        -0.081939
#              genre         -0.334021
#              year           0.309212
#              released       0.009145
#              score          0.056609
#              votes          0.555783
#              director       0.004976
#              writer        -0.025911
#              star          -0.019952
#              country        0.131720
#              budget         1.000000
#              gross          0.750157
#              company        0.186474
#              runtime        0.280730
#              yearcorrect    0.300236
# gross        name           0.006989
#              rating        -0.095450
#              genre         -0.234297
#              year           0.261900
#              released       0.000519
#              score          0.186490
#              votes          0.637628
#              director      -0.014916
#              writer        -0.022997
#              star          -0.001129
#              country        0.095325
#              budget         0.750157
#              gross          1.000000
#              company        0.156745
#              runtime        0.255656
#              yearcorrect    0.255130
# company      name           0.009211
#              rating        -0.032943
#              genre         -0.071067
#              year          -0.010431
#              released      -0.010474
#              score          0.003911
#              votes          0.168983
#              director       0.004404
#              writer         0.005646
#              star           0.012442
#              country        0.095548
#              budget         0.186474
#              gross          0.156745
#              company        1.000000
#              runtime        0.036970
#              yearcorrect   -0.014144
# runtime      name           0.009920
#              rating         0.067150
#              genre         -0.057637
#              year           0.125994
#              released       0.000641
#              score          0.406004
#              votes          0.337200
#              director       0.018408
#              writer        -0.004417
#              star           0.009449
#              country       -0.076787
#              budget         0.280730
#              gross          0.255656
#              company        0.036970
#              runtime        1.000000
#              yearcorrect    0.127376
# yearcorrect  name           0.010225
#              rating         0.006403
#              genre         -0.078210
#              year           0.996397
#              released      -0.003775
#              score          0.102718
#              votes          0.349291
#              director      -0.020385
#              writer        -0.008391
#              star          -0.027606
#              country       -0.079009
#              budget         0.300236
#              gross          0.255130
#              company       -0.014144
#              runtime        0.127376
#              yearcorrect    1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.334021
# budget       genre         -0.334021
# gross        genre         -0.234297
# genre        gross         -0.234297
#              votes         -0.185332
# votes        genre         -0.185332
# score        country       -0.133644
# country      score         -0.133644
# gross        rating        -0.095450
# rating       gross         -0.095450
#              budget        -0.081939
# budget       rating        -0.081939
# year         genre         -0.081261
# genre        year          -0.081261
# yearcorrect  country       -0.079009
# country      yearcorrect   -0.079009
# yearcorrect  genre         -0.078210
# genre        yearcorrect   -0.078210
# runtime      country       -0.076787
# country      runtime       -0.076787
# genre        company       -0.071067
# company      genre         -0.071067
# country      year          -0.070938
# year         country       -0.070938
# genre        runtime       -0.057637
# runtime      genre         -0.057637
# country      genre         -0.037615
# genre        country       -0.037615
# rating       company       -0.032943
# company      rating        -0.032943
# star         yearcorrect   -0.027606
# yearcorrect  star          -0.027606
# star         year          -0.027242
# year         star          -0.027242
# budget       writer        -0.025911
# writer       budget        -0.025911
#              gross         -0.022997
# gross        writer        -0.022997
# votes        star          -0.020851
# star         votes         -0.020851
# year         director      -0.020795
# director     year          -0.020795
# country      released      -0.020427
# released     country       -0.020427
# director     yearcorrect   -0.020385
# yearcorrect  director      -0.020385
# budget       star          -0.019952
# star         budget        -0.019952
# genre        director      -0.015258
# director     genre         -0.015258
# gross        director      -0.014916
# director     gross         -0.014916
# company      yearcorrect   -0.014144
# yearcorrect  company       -0.014144
# country      star          -0.012998
# star         country       -0.012998
# name         released      -0.011311
# released     name          -0.011311
# name         country       -0.010737
# country      name          -0.010737
# company      released      -0.010474
# released     company       -0.010474
# year         company       -0.010431
# company      year          -0.010431
# writer       year          -0.008656
# year         writer        -0.008656
# yearcorrect  writer        -0.008391
# writer       yearcorrect   -0.008391
# name         rating        -0.008069
# rating       name          -0.008069
#              writer        -0.005921
# writer       rating        -0.005921
# star         genre         -0.005477
# genre        star          -0.005477
# writer       runtime       -0.004417
# runtime      writer        -0.004417
# released     yearcorrect   -0.003775
# yearcorrect  released      -0.003775
# writer       released      -0.002404
# released     writer        -0.002404
# director     released      -0.001478
# released     director      -0.001478
# star         gross         -0.001129
# gross        star          -0.001129
# year         released      -0.000695
# released     year          -0.000695
# score        star          -0.000542
# star         score         -0.000542
# gross        released       0.000519
# released     gross          0.000519
#              runtime        0.000641
# runtime      released       0.000641
# released     votes          0.002601
# votes        released       0.002601
# company      score          0.003911
# score        company        0.003911
#              rating         0.003950
# rating       score          0.003950
# director     company        0.004404
# company      director       0.004404
# budget       director       0.004976
# director     budget         0.004976
# company      writer         0.005646
# writer       company        0.005646
# rating       yearcorrect    0.006403
# yearcorrect  rating         0.006403
# star         name           0.006472
# name         star           0.006472
# genre        writer         0.006567
# writer       genre          0.006567
# gross        name           0.006989
# name         gross          0.006989
# director     votes          0.007427
# votes        director       0.007427
# name         votes          0.007497
# votes        name           0.007497
#              writer         0.007744
# writer       votes          0.007744
# year         rating         0.008779
# rating       year           0.008779
# director     name           0.009079
# name         director       0.009079
# writer       name           0.009081
# name         writer         0.009081
# released     budget         0.009145
# budget       released       0.009145
# company      name           0.009211
# name         company        0.009211
# star         runtime        0.009449
# runtime      star           0.009449
#              name           0.009920
# name         runtime        0.009920
#              yearcorrect    0.010225
# yearcorrect  name           0.010225
# score        director       0.010307
# director     score          0.010307
# name         year           0.011453
# year         name           0.011453
# star         company        0.012442
# company      star           0.012442
# star         rating         0.013405
# rating       star           0.013405
# country      writer         0.015343
# writer       country        0.015343
# released     star           0.015777
# star         released       0.015777
# name         genre          0.016355
# genre        name           0.016355
# score        name           0.016598
# name         score          0.016598
# rating       released       0.016613
# released     rating         0.016613
# country      director       0.017490
# director     country        0.017490
#              runtime        0.018408
# runtime      director       0.018408
# director     rating         0.019483
# rating       director       0.019483
# budget       name           0.020548
# name         budget         0.020548
# score        writer         0.021313
# writer       score          0.021313
#              star           0.027245
# star         writer         0.027245
# score        genre          0.027592
# genre        score          0.027592
#              released       0.029822
# released     genre          0.029822
# company      runtime        0.036970
# runtime      company        0.036970
# star         director       0.039234
# director     star           0.039234
# released     score          0.040699
# score        released       0.040699
#              budget         0.056609
# budget       score          0.056609
# runtime      rating         0.067150
# rating       runtime        0.067150
#              genre          0.072423
# genre        rating         0.072423
# votes        rating         0.074561
# rating       votes          0.074561
#              country        0.081244
# country      rating         0.081244
#              votes          0.083126
# votes        country        0.083126
# year         score          0.094416
# score        year           0.094416
# country      gross          0.095325
# gross        country        0.095325
# country      company        0.095548
# company      country        0.095548
# score        yearcorrect    0.102718
# yearcorrect  score          0.102718
# runtime      year           0.125994
# year         runtime        0.125994
# runtime      yearcorrect    0.127376
# yearcorrect  runtime        0.127376
# country      budget         0.131720
# budget       country        0.131720
# company      gross          0.156745
# gross        company        0.156745
# votes        company        0.168983
# company      votes          0.168983
# budget       company        0.186474
# company      budget         0.186474
# gross        score          0.186490
# score        gross          0.186490
# yearcorrect  gross          0.255130
# gross        yearcorrect    0.255130
# runtime      gross          0.255656
# gross        runtime        0.255656
# year         gross          0.261900
# gross        year           0.261900
# runtime      budget         0.280730
# budget       runtime        0.280730
# writer       director       0.299067
# director     writer         0.299067
# budget       yearcorrect    0.300236
# yearcorrect  budget         0.300236
# year         budget         0.309212
# budget       year           0.309212
# runtime      votes          0.337200
# votes        runtime        0.337200
#              yearcorrect    0.349291
# yearcorrect  votes          0.349291
# year         votes          0.355072
# votes        year           0.355072
# runtime      score          0.406004
# score        runtime        0.406004
#              votes          0.458517
# votes        score          0.458517
#              budget         0.555783
# budget       votes          0.555783
# gross        votes          0.637628
# votes        gross          0.637628
# gross        budget         0.750157
# budget       gross          0.750157
# year         yearcorrect    0.996397
# yearcorrect  year           0.996397
# director     director       1.000000
# votes        votes          1.000000
# released     released       1.000000
# score        score          1.000000
# rating       rating         1.000000
# name         name           1.000000
# genre        genre          1.000000
# year         year           1.000000
# budget       budget         1.000000
# country      country        1.000000
# writer       writer         1.000000
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#Extragem valorile > 0.5
high_cor = sorted_pairs[(sorted_pairs)>0.5]
high_cor
# Out:
# votes        budget         0.555783
# budget       votes          0.555783
# gross        votes          0.637628
# votes        gross          0.637628
# gross        budget         0.750157
# budget       gross          0.750157
# year         yearcorrect    0.996397
# yearcorrect  year           0.996397
# director     director       1.000000
# votes        votes          1.000000
# released     released       1.000000
# score        score          1.000000
# rating       rating         1.000000
# name         name           1.000000
# genre        genre          1.000000
# year         year           1.000000
# budget       budget         1.000000
# country      country        1.000000
# writer       writer         1.000000
# star         star           1.000000
# company      company        1.000000
# gross        gross          1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#Obsrvam cele mai mari valori intre gross si budget si intre gross si votes
